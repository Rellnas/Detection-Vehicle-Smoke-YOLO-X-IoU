# %%
# !nvidia-smi
# Out:
# Thu May  1 02:25:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             46W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import os
#HOME = os.getcwd()
HOME = "/content/drive/MyDrive/TA/MODEL"
print(HOME)
# Out:
# /content/drive/MyDrive/TA/MODEL

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 41.1/235.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/dataset
# %cd {HOME}/dataset

# !pip install roboflow

# https://app.roboflow.com/ta-gomsn/vehicle-smoke-pollution/27 -> Dataset
# Out:
# /content/drive/MyDrive/TA/MODEL/dataset
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 144.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to vehicle-smoke-pollution-27 in yolov8:: 100%|██████████| 24710/24710 [02:21<00:00, 175.21it/s]

# %%
import torch
print(torch.cuda.is_available())  # Harus mengembalikan True jika GPU terdeteksi
print(torch.cuda.device_count())  # Menampilkan jumlah GPU yang tersedia
print(torch.cuda.get_device_name(0))  # Menampilkan nama GPU yang terdeteksi
# Out:
# True
# 1
# NVIDIA A100-SXM4-40GB

# %%
# %cd {HOME}/dataset

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 imgsz=800 plots=True \
    project=/content/drive/MyDrive/TA/model_checkpoints \
    name=YOLOv8s \
    save=True \
    save_period=10 \
    device=0
# Out:
# /content/drive/MyDrive/TA/MODEL/dataset
# ...
# 100% 21.5M/21.5M [00:00<00:00, 344MB/s]
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# %cd {HOME}/dataset

# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/TA/MODEL/dataset/vehicle-smoke-pollution-27/data.yaml epochs=100 imgsz=800 plots=True \
    project=/content/drive/MyDrive/TA/model_checkpoints \
    name=YOLOv8n \
    save=True \
    save_period=10 \
    device=0
# Out:
# /content/drive/MyDrive/TA/MODEL/dataset
# ...
# 100% 6.25M/6.25M [00:00<00:00, 275MB/s]
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# %cd {HOME}/dataset

# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/TA/MODEL/dataset/vehicle-smoke-pollution-27/data.yaml epochs=100 imgsz=800 plots=True \
    project=/content/drive/MyDrive/TA/model_checkpoints \
    name=YOLOv8m \
    save=True \
    save_period=10 \
    device=0
# Out:
# /content/drive/MyDrive/TA/MODEL/dataset
# ...
# 100% 49.7M/49.7M [00:00<00:00, 227MB/s]
# Ultralytics 8.3.122 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...
